# %%
from Task2 import whatjob

# %%
whatJobClass=whatjob()
train_df,valid_df,test_df=whatJobClass.getData()

# %%
#batchTraining
#train_df_clean=whatJobClass.cleanText(train_df,train_flag=True)
#clf=whatJobClass.batchTraining(train_df_clean)

# %%
#valBatchEval
valid_df_clean=whatJobClass.cleanText(valid_df,train_flag=False)
_,_=whatJobClass.valBatchEval(valid_df_clean)
# Out:
#                               precision    recall  f1-score   support
#
#             Backend Engineer      0.936     0.910     0.923      1127
#              Cloud architect      0.929     0.839     0.881       124
#             Customer Support      0.975     0.986     0.980       784
#                 Data Analyst      0.875     0.912     0.893       261
#                 Data Science      0.953     0.909     0.930       788
#      Database Administration      0.930     0.869     0.898       122
#                       Design      0.987     0.962     0.974       787
#           Front End Engineer      0.933     0.916     0.924       273
#          Full Stack Engineer      0.948     0.949     0.949       728
#         Information Security      0.945     0.929     0.937       112
# Mobile Application Developer      0.991     0.926     0.957       229
#       Network Administration      0.814     0.891     0.851        64
#                       Non-IT      0.912     0.965     0.937      2265
#           Product Management      0.958     0.950     0.954       899
#           Project Management      0.952     0.960     0.956       994
#            Technical Support      0.920     0.860     0.889       443
#
#                     accuracy                          0.941     10000
#                    macro avg      0.935     0.921     0.927     10000
#                 weighted avg      0.941     0.941     0.941     10000

# %%
#testBatch
test_df_clean=whatJobClass.cleanText(test_df,train_flag=False)
y_pred=whatJobClass.testBatch(valid_df_clean)

# %%
#testSample
job_title='Technical Lead (QA Automation)'
y_pred_single=whatJobClass.testSample(job_title)
print(y_pred_single)
# Out:
# ['Product Management']
